# %%
# !pip install kaggle

# %%
# !kaggle datasets download -d jesucristo/mit-5k-basic

# %%
# !unzip mit-5k-basic.zip

# %%
# !git clone https://github.com/SnehamayRoy/Image-Enhancement-using-CycleGAN.git

# %%
# %cd /content/Image-Enhancement-using-CycleGAN
# Out:
# /content/Image-Enhancement-using-CycleGAN

# %%
# %ls
# Out:
# config.py  dataset.py              generator_model.py  README.md      train.py
# data/      discriminator_model.py  __pycache__/        saved_images/  utils.py

# %%
# !pip install -U albumentations

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !python train.py
