# %%
# !git clone https://github.com/SnehamayRoy/Image-Enhancement-using-CycleGAN.git

# %%
# %cd Image-Enhancement-using-CycleGAN

# %%
# !pip install -U albumentations

# %%
# %ls
# Out:
# config.py                    dataset.py              genh.pth.tar  result.md      test_results/
# CycleGAN_for_Training.ipynb  discriminator_model.py  genz.pth.tar  saved_images/  train.py
# data/                        generator_model.py      README.md     test.py        utils.py

# %% [markdown]
# Get the trained model/Pretained model

# %%
# !gdown --folder 'Folder ID'
#To download the pretrained model from google drive, use folder id 
#For example folder id of 'https://drive.google.com/drive/folders/1pTyeIEOIgyGiJtLXw9tewy2RIMPuqwZ3?usp=sharing' would be '1pTyeIEOIgyGiJtLXw9tewy2RIMPuqwZ3'

# %% [markdown]
# Check GPU Availability

# %%
import torch
torch.cuda.is_available()

# %%
# !python test.py
